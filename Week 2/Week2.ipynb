# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('adult_data.csv')

# %%
df.head(10)
# Out:
#    age          workclass  fnlwgt      education  education_num  \
# 0   38            Private  215646        HS-grad              9
# 1   53            Private  234721           11th              7
# 2   28            Private  338409      Bachelors             13
# 3   37            Private  284582        Masters             14
# 4   49            Private  160187            9th              5
# 5   52   Self-emp-not-inc  209642        HS-grad              9
# 6   31            Private   45781        Masters             14
# 7   42            Private  159449      Bachelors             13
# 8   37            Private  280464   Some-college             10
# 9   30          State-gov  141297      Bachelors             13
#
#            marital_status          occupation    relationship  \
# 0                Divorced   Handlers-cleaners   Not-in-family
# 1      Married-civ-spouse   Handlers-cleaners         Husband
# 2      Married-civ-spouse      Prof-specialty            Wife
# 3      Married-civ-spouse     Exec-managerial            Wife
# 4   Married-spouse-absent       Other-service   Not-in-family
# 5      Married-civ-spouse     Exec-managerial         Husband
# 6           Never-married      Prof-specialty   Not-in-family
# 7      Married-civ-spouse     Exec-managerial         Husband
# 8      Married-civ-spouse     Exec-managerial         Husband
# 9      Married-civ-spouse      Prof-specialty         Husband
#
#                   race      sex  capital_gain  capital_loss  hours_per_week  \
# 0                White     Male             0             0              40
# 1                Black     Male             0             0              40
# 2                Black   Female             0             0              40
# 3                White   Female             0             0              40
# 4                Black   Female             0             0              16
# 5                White     Male             0             0              45
# 6                White   Female         14084             0              50
# 7                White     Male          5178             0              40
# 8                Black     Male             0             0              80
# 9   Asian-Pac-Islander     Male             0             0              40
#
#    native_country  income
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2            Cuba   <=50K
# 3   United-States   <=50K
# 4         Jamaica   <=50K
# 5   United-States    >50K
# 6   United-States    >50K
# 7   United-States    >50K
# 8   United-States    >50K
# 9           India    >50K

# %%
df.tail(10)
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 32549   32        Private   34066           10th              6
# 32550   43        Private   84661      Assoc-voc             11
# 32551   32        Private  116138        Masters             14
# 32552   53        Private  321865        Masters             14
# 32553   22        Private  310152   Some-college             10
# 32554   27        Private  257302     Assoc-acdm             12
# 32555   40        Private  154374        HS-grad              9
# 32556   58        Private  151910        HS-grad              9
# 32557   22        Private  201490        HS-grad              9
# 32558   52   Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 32549   Married-civ-spouse   Handlers-cleaners         Husband
# 32550   Married-civ-spouse               Sales         Husband
# 32551        Never-married        Tech-support   Not-in-family
# 32552   Married-civ-spouse     Exec-managerial         Husband
# 32553        Never-married     Protective-serv   Not-in-family
# 32554   Married-civ-spouse        Tech-support            Wife
# 32555   Married-civ-spouse   Machine-op-inspct         Husband
# 32556              Widowed        Adm-clerical       Unmarried
# 32557        Never-married        Adm-clerical       Own-child
# 32558   Married-civ-spouse     Exec-managerial            Wife
#
#                       race      sex  capital_gain  capital_loss  \
# 32549   Amer-Indian-Eskimo     Male             0             0
# 32550                White     Male             0             0
# 32551   Asian-Pac-Islander     Male             0             0
# 32552                White     Male             0             0
# 32553                White     Male             0             0
# 32554                White   Female             0             0
# 32555                White     Male             0             0
# 32556                White   Female             0             0
# 32557                White     Male             0             0
# 32558                White   Female         15024             0
#
#        hours_per_week  native_country  income
# 32549              40   United-States   <=50K
# 32550              45   United-States   <=50K
# 32551              11          Taiwan   <=50K
# 32552              40   United-States    >50K
# 32553              40   United-States   <=50K
# 32554              38   United-States   <=50K
# 32555              40   United-States    >50K
# 32556              40   United-States   <=50K
# 32557              20   United-States   <=50K
# 32558              40   United-States    >50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32559 entries, 0 to 32558
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32559 non-null  int64
#  1   workclass       32559 non-null  object
#  2   fnlwgt          32559 non-null  int64
#  3   education       32559 non-null  object
#  4   education_num   32559 non-null  int64
#  5   marital_status  32559 non-null  object
#  6   occupation      32559 non-null  object
#  7   relationship    32559 non-null  object
#  8   race            32559 non-null  object
#  9   sex             32559 non-null  object
#  10  capital_gain    32559 non-null  int64
#  11  capital_loss    32559 non-null  int64
#  12  hours_per_week  32559 non-null  int64
#  13  native_country  32559 non-null  object
#  14  income          32559 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32559.000000     32559  3.255900e+04     32559   32559.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581283       NaN  1.897851e+05       NaN      10.080500
# std        13.640705       NaN  1.055497e+05       NaN       2.572698
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178330e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783700e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370580e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital_status       occupation relationship    race    sex  \
# count                 32559            32559        32559   32559  32559
# unique                    7               15            6       5      2
# top      Married-civ-spouse   Prof-specialty      Husband   White   Male
# freq                  14975             4140        13192   27814  21788
# mean                    NaN              NaN          NaN     NaN    NaN
# std                     NaN              NaN          NaN     NaN    NaN
# min                     NaN              NaN          NaN     NaN    NaN
# 25%                     NaN              NaN          NaN     NaN    NaN
# 50%                     NaN              NaN          NaN     NaN    NaN
# 75%                     NaN              NaN          NaN     NaN    NaN
# max                     NaN              NaN          NaN     NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week  native_country  income
# count   32559.000000  32559.000000    32559.000000           32559   32559
# unique           NaN           NaN             NaN              42       2
# top              NaN           NaN             NaN   United-States   <=50K
# freq             NaN           NaN             NaN           29168   24718
# mean     1077.648269     87.309193       40.438312             NaN     NaN
# std      7385.514002    402.972014       12.346871             NaN     NaN
# min         0.000000      0.000000        1.000000             NaN     NaN
# 25%         0.000000      0.000000       40.000000             NaN     NaN
# 50%         0.000000      0.000000       40.000000             NaN     NaN
# 75%         0.000000      0.000000       45.000000             NaN     NaN
# max     99999.000000   4356.000000       99.000000             NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32559 entries, 0 to 32558
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32559 non-null  int64
#  1   workclass       32559 non-null  object
#  2   fnlwgt          32559 non-null  int64
#  3   education       32559 non-null  object
#  4   education_num   32559 non-null  int64
#  5   marital_status  32559 non-null  object
#  6   occupation      32559 non-null  object
#  7   relationship    32559 non-null  object
#  8   race            32559 non-null  object
#  9   sex             32559 non-null  object
#  10  capital_gain    32559 non-null  int64
#  11  capital_loss    32559 non-null  int64
#  12  hours_per_week  32559 non-null  int64
#  13  native_country  32559 non-null  object
#  14  income          32559 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32559, 15)

# %%
from sqlalchemy import create_engine

# %%
host = r'127.0.0.1' # denotes that the db in a local installation
db = r'MSDS610' # db we just created
user = r'postgres' # using the postgres user for this demo
pw = r'MSDS610' # this is the password established during installation
port = r'5432' # default port estabalished during install
schema = r'raw' # schema we just created

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %%
sql="select tables.table_name from information_schema.tables where (table_schema ='"+schema+"')order by 1;"
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
# Empty DataFrame
# Columns: [table_name]
# Index: []

# %%
table_name = r'adult_data'

# %%
df.to_sql(table_name, con=db_conn, if_exists='replace', index=False, schema=schema, chunksize=1000, method='multi')
# Out:
# 32559

# %%
table_df = pd.read_sql(sql, db_conn, index_col=None)
table_df
# Out:
#    table_name
# 0  adult_data

# %%
sql=r'SELECT * FROM ' + schema + '.' + table_name
df_check = pd.read_sql(sql, db_conn, index_col=None)

# %%
df_check.head(10)
# Out:
#    age          workclass  fnlwgt      education  education_num  \
# 0   38            Private  215646        HS-grad              9
# 1   53            Private  234721           11th              7
# 2   28            Private  338409      Bachelors             13
# 3   37            Private  284582        Masters             14
# 4   49            Private  160187            9th              5
# 5   52   Self-emp-not-inc  209642        HS-grad              9
# 6   31            Private   45781        Masters             14
# 7   42            Private  159449      Bachelors             13
# 8   37            Private  280464   Some-college             10
# 9   30          State-gov  141297      Bachelors             13
#
#            marital_status          occupation    relationship  \
# 0                Divorced   Handlers-cleaners   Not-in-family
# 1      Married-civ-spouse   Handlers-cleaners         Husband
# 2      Married-civ-spouse      Prof-specialty            Wife
# 3      Married-civ-spouse     Exec-managerial            Wife
# 4   Married-spouse-absent       Other-service   Not-in-family
# 5      Married-civ-spouse     Exec-managerial         Husband
# 6           Never-married      Prof-specialty   Not-in-family
# 7      Married-civ-spouse     Exec-managerial         Husband
# 8      Married-civ-spouse     Exec-managerial         Husband
# 9      Married-civ-spouse      Prof-specialty         Husband
#
#                   race      sex  capital_gain  capital_loss  hours_per_week  \
# 0                White     Male             0             0              40
# 1                Black     Male             0             0              40
# 2                Black   Female             0             0              40
# 3                White   Female             0             0              40
# 4                Black   Female             0             0              16
# 5                White     Male             0             0              45
# 6                White   Female         14084             0              50
# 7                White     Male          5178             0              40
# 8                Black     Male             0             0              80
# 9   Asian-Pac-Islander     Male             0             0              40
#
#    native_country  income
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2            Cuba   <=50K
# 3   United-States   <=50K
# 4         Jamaica   <=50K
# 5   United-States    >50K
# 6   United-States    >50K
# 7   United-States    >50K
# 8   United-States    >50K
# 9           India    >50K
